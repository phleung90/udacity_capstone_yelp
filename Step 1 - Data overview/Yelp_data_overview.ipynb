# %% [markdown]
# ## Exploratory data analysis and basic data transformation - yelp
#
# ### This workbook aims to illustrate the process in:
# - Extract part of the data from the source file
# - Load the data into a pandas dataframe
# - Transform and process the data
# - Save the outfile as an csv

# %%
# Import the packages 
import numpy as np
import pandas as pd
import os
import json
from datetime import datetime

# %%
# Print the available dataset 
# Read the data locally
filepath = 'D:\yelp_dataset'

arr = os.listdir(filepath)
print(arr)
# Out:
# ['Dataset_User_Agreement.pdf', 'yelp_academic_dataset_business.json', 'yelp_academic_dataset_business_sample.json', 'yelp_academic_dataset_business_sample_output.csv', 'yelp_academic_dataset_checkin.json', 'yelp_academic_dataset_checkin_sample.json', 'yelp_academic_dataset_checkin_sample_output.csv', 'yelp_academic_dataset_covid_features.json', 'yelp_academic_dataset_review.json', 'yelp_academic_dataset_review_sample.json', 'yelp_academic_dataset_review_sample_output.csv', 'yelp_academic_dataset_tip.json', 'yelp_academic_dataset_tip_sample.json', 'yelp_academic_dataset_tip_sample_output.csv', 'yelp_academic_dataset_user.json', 'yelp_academic_dataset_user_sample.json', 'yelp_academic_dataset_user_sample_output.csv']

# %% [markdown]
# ## Business data set
# Source file: yelp_academic_dataset_business.json

# %%
# Write the first 1000 rows of json data into a sample file 
with open(filepath + '\yelp_academic_dataset_business.json', 'r', encoding='utf-8') as json_in_file: 
    with open(filepath + '\yelp_academic_dataset_business_sample.json', 'w', encoding='utf-8') as json_out_file:
        for index, line in enumerate(json_in_file): 
            json_out_file.write(line)
            if index > 1000:
                break

# %%
# Load the json data into a list 
business_sample_data = []

with open(filepath + '\yelp_academic_dataset_business_sample.json', 'r', encoding='utf-8') as sample_file:
    for lines in sample_file: 
        business_sample_data.append(json.loads(lines))

# %%
# Read sample data
business_sample_data[20:25]
# Out:
# [{'business_id': 'DLbEQySMW3X7KvkybpEYkw',
#   'name': 'Jasmine Nail Spa',
#   'address': '4370 SE King Rd, Ste 125',
#   'city': 'Portland',
#   'state': 'OR',
#   'postal_code': '97222',
#   'latitude': 45.4475976,
#   'longitude': -122.6174267,
#   'stars': 3.0,
#   'review_count': 7,
#   'is_open': 0,
#   'attributes': {'RestaurantsPriceRange2': '1', 'ByAppointmentOnly': 'False'},
#   'categories': 'Nail Salons, Beauty & Spas',
#   'hours': {'Monday': '9:30-18:0',
#    'Tuesday': '9:30-18:0',
#    'Wednesday': '9:30-18:0',
#    'Thursday': '9:30-18:0',
#    'Friday': '9:30-18:0',
#    'Saturday': '9:30-16:0'}},
#  {'business_id': 'AvT2mGkdYwU0ghqDfs-OlQ',
#   'name': 'Tire Town Auto Service',
#   'address': '2032 Hastings Street E',
#   'city': 'Vancouver',
#   'state': 'BC',
#   'postal_code': 'V5L 1T8',
#   'latitude': 49.2810588,
#   'longitude': -123.0630193,
#   'stars': 4.0,
#   'review_count': 6,
#   'is_open': 0,
#   'attributes': None,
#   'categories': 'Auto Repair, Automotive, Tires',
#   'hours': {'Monday': '9:0-17:30',
#    'Tuesday': '9:0-17:30',
#    'Wednesday': '9:0-17:30',
#    'Thursday': '9:0-17:30',
#    'Friday': '9:0-17:30',
#    'Saturday': '9:0-17:0'}},
#  {'business_id': 'ynTjh_FdhbG5hY69HsEoaA',
#   'name': 'Cascade Restaurant',
#   'address': 'Hyatt Regency Grand Cypress, 1 Grand Cypress Blvd',
#   'city': 'Orlando',
#   'state': 'FL',
#   'postal_code': '32836',
#   'latitude': 28.3819454,
#   'longitude': -81.510327,
#   'stars': 3.5,
#   'review_count': 18,
#   'is_open': 0,
#   'attributes': {'OutdoorSeating': 'True',
#    'RestaurantsAttire': "u'casual'",
#    'HasTV': 'True',
#    'GoodForKids': 'True',
#    'Ambience': "{'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}",
#    'RestaurantsPriceRange2': '2',
#    'RestaurantsReservations': 'True',
#    'RestaurantsGoodForGroups': 'True',
#    'RestaurantsTakeOut': 'True',
#    'RestaurantsDelivery': 'False',
#    'BusinessAcceptsBitcoin': 'False',
#    'Alcohol': "'full_bar'",
#    'BusinessAcceptsCreditCards': 'True',
#    'BikeParking': 'True',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': True, 'lot': True, 'valet': True}",
#    'WiFi': "'free'",
#    'NoiseLevel': "u'average'",
#    'Caters': 'True'},
#   'categories': 'Hotels, American (Traditional), Restaurants, Event Planning & Services, Hotels & Travel',
#   'hours': {'Monday': '7:0-22:0',
#    'Tuesday': '7:0-22:0',
#    'Wednesday': '7:0-22:0',
#    'Thursday': '7:0-22:0',
#    'Friday': '7:0-22:0',
#    'Saturday': '7:0-22:0',
#    'Sunday': '7:0-22:0'}},
#  {'business_id': 'j68RDnvOaYEwGcY9cTEHpA',
#   'name': 'Pittock Mansion',
#   'address': '3229 NW Pittock Dr',
#   'city': 'Portland',
#   'state': 'OR',
#   'postal_code': '97210',
#   'latitude': 45.5252593,
#   'longitude': -122.7162265,
#   'stars': 4.5,
#   'review_count': 406,
#   'is_open': 1,
#   'attributes': {'BusinessAcceptsCreditCards': 'True',
#    'GoodForKids': 'True',
#    'ByAppointmentOnly': 'False',
#    'RestaurantsAttire': "u'casual'"},
#   'categories': 'Tours, Museums, Architectural Tours, Venues & Event Spaces, Landmarks & Historical Buildings, Hotels & Travel, Arts & Entertainment, Community Service/Non-Profit, Local Services, Event Planning & Services, Public Services & Government, Historical Tours',
#   'hours': {'Monday': '0:0-0:0',
#    'Thursday': '10:0-16:0',
#    'Friday': '10:0-16:0',
#    'Saturday': '10:0-16:0',
#    'Sunday': '10:0-16:0'}},
#  {'business_id': 'nTIhpR7MhsALPwg_Hh14EA',
#   'name': 'DoubleTree by Hilton Hotel Austin',
#   'address': '6505 N Interstate 35',
#   'city': 'Austin',
#   'state': 'TX',
#   'postal_code': '78752',
#   'latitude': 30.3263767015,
#   'longitude': -97.7045434713,
#   'stars': 3.0,
#   'review_count': 139,
#   'is_open': 1,
#   'attributes': {'WiFi': "u'free'",
#    'RestaurantsPriceRange2': '2',
#    'BusinessAcceptsCreditCards': 'True'},
#   'categories': 'Hotels, Hotels & Travel, Event Planning & Services',
#   'hours': {'Monday': '0:0-0:0',
#    'Tuesday': '0:0-0:0',
#    'Wednesday': '0:0-0:0',
#    'Thursday': '0:0-0:0',
#    'Friday': '0:0-0:0',
#    'Saturday': '0:0-0:0',
#    'Sunday': '0:0-0:0'}}]

# %% [markdown]
# Since it is a list of nested dict, it is necessary to flatten the nested dict before loading it to pandas dataframe

# %%
# Flatten the nested json
def flatten_nested_dict(d):
    output = {}
    
    for k,v in d.items():
        if isinstance(v, dict):
            v = [v]
        if isinstance(v, list): 
            for subdict in v:
                deeper = flatten_nested_dict(subdict).items()
                output.update({k + '_' + key2: val2 for key2, val2 in deeper})
        else: 
            output[k] = v
    
    return output

business_data_list = []
for items in range(0, len(business_sample_data)): 
    flatten_business_data = flatten_nested_dict(business_sample_data[items])
    business_data_list.append(flatten_business_data)

# %%
business_data = pd.DataFrame(business_data_list)
business_data
# Out:
#                  business_id                         name  \
# 0     6iYb2HFDywm3zjuRg0shjw          Oskar Blues Taproom
# 1     tCbdrRPZA0oiIYSmHG3J0w      Flying Elephants at PDX
# 2     bvN78flM8NLprQ1a1y5dRg               The Reclaimory
# 3     oaepsyvc0J17qwi8cfrOWg                  Great Clips
# 4     PE9uqAjdw0E4-8mjGl3wVA            Crossfit Terminus
# ...                      ...                          ...
# 997   9irir2PpYr_yY5lNWYqUWA         Subaru North Orlando
# 998   2cG2YiR8Tg-YCJJfaHJtYw   Elements Massage - Medford
# 999   OhpdMOXon32xdJ0-OeL5-Q                Pirate's Cove
# 1000  ivR_bKFNBaEiHfPYDPkFSg           Tony's Nails & Spa
# 1001  FckiBr0rL7Apg0qv6qHI0g  Advanced Dental Care Center
#
#                      address         city state postal_code   latitude  \
# 0               921 Pearl St      Boulder    CO       80302  40.017544
# 1        7000 NE Airport Way     Portland    OR       97218  45.588906
# 2         4720 Hawthorne Ave     Portland    OR       97214  45.511907
# 3         2566 Enterprise Rd  Orange City    FL       32763  28.914482
# 4        1046 Memorial Dr SE      Atlanta    GA       30316  33.747027
# ...                      ...          ...   ...         ...        ...
# 997        4113 S Orlando Dr      Sanford    FL       32773  28.749161
# 998               40 High St      Medford    MA       02155  42.418388
# 999       7417 NE Sandy Blvd     Portland    OR       97213  45.549482
# 1000     2105 Lavista Rd 112      Atlanta    GA       30329  33.814607
# 1001  5144 Morse Rd, Ste 200     Columbus    OH       43230  40.055345
#
#        longitude  stars  review_count  ...  attributes_GoodForDancing  \
# 0    -105.283348    4.0            86  ...                        NaN
# 1    -122.593331    4.0           126  ...                        NaN
# 2    -122.613693    4.5            13  ...                        NaN
# 3     -81.295979    3.0             8  ...                        NaN
# 4     -84.353424    4.0            14  ...                        NaN
# ...          ...    ...           ...  ...                        ...
# 997   -81.291087    4.0            32  ...                        NaN
# 998   -71.111116    4.0            55  ...                        NaN
# 999  -122.586522    3.5            19  ...                        NaN
# 1000  -84.312023    3.5            64  ...                        NaN
# 1001  -82.855041    5.0            10  ...                        NaN
#
#      attributes_BestNights attributes_Music attributes_BYOB  \
# 0                      NaN              NaN             NaN
# 1                      NaN              NaN             NaN
# 2                      NaN              NaN             NaN
# 3                      NaN              NaN             NaN
# 4                      NaN              NaN             NaN
# ...                    ...              ...             ...
# 997                    NaN              NaN             NaN
# 998                    NaN              NaN             NaN
# 999                    NaN              NaN             NaN
# 1000                   NaN              NaN             NaN
# 1001                   NaN              NaN             NaN
#
#      attributes_CoatCheck attributes_Smoking attributes_DriveThru  \
# 0                     NaN                NaN                  NaN
# 1                     NaN                NaN                  NaN
# 2                     NaN                NaN                  NaN
# 3                     NaN                NaN                  NaN
# 4                     NaN                NaN                  NaN
# ...                   ...                ...                  ...
# 997                   NaN                NaN                  NaN
# 998                   NaN                NaN                  NaN
# 999                   NaN                NaN                  NaN
# 1000                  NaN                NaN                  NaN
# 1001                  NaN                NaN                  NaN
#
#      attributes_BYOBCorkage attributes_Corkage  \
# 0                       NaN                NaN
# 1                       NaN                NaN
# 2                       NaN                NaN
# 3                       NaN                NaN
# 4                       NaN                NaN
# ...                     ...                ...
# 997                     NaN                NaN
# 998                     NaN                NaN
# 999                     NaN                NaN
# 1000                    NaN                NaN
# 1001                    NaN                NaN
#
#      attributes_RestaurantsCounterService
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 997                                   NaN
# 998                                   NaN
# 999                                   NaN
# 1000                                  NaN
# 1001                                  NaN
#
# [1002 rows x 57 columns]

# %% [markdown]
# To achiever the goal, we need the following columns:
# - business_id,
# - name,
# - address,
# - city,
# - state,
# - postal_code,
# - stars,
# - review_count
# - is_open
# - categories

# %%
business_data = business_data[['business_id', 'name', 'address', 'city', 'state', 'postal_code', 'stars', 'review_count', 'is_open', 'categories']]
business_data
# Out:
#                  business_id                         name  \
# 0     6iYb2HFDywm3zjuRg0shjw          Oskar Blues Taproom
# 1     tCbdrRPZA0oiIYSmHG3J0w      Flying Elephants at PDX
# 2     bvN78flM8NLprQ1a1y5dRg               The Reclaimory
# 3     oaepsyvc0J17qwi8cfrOWg                  Great Clips
# 4     PE9uqAjdw0E4-8mjGl3wVA            Crossfit Terminus
# ...                      ...                          ...
# 997   9irir2PpYr_yY5lNWYqUWA         Subaru North Orlando
# 998   2cG2YiR8Tg-YCJJfaHJtYw   Elements Massage - Medford
# 999   OhpdMOXon32xdJ0-OeL5-Q                Pirate's Cove
# 1000  ivR_bKFNBaEiHfPYDPkFSg           Tony's Nails & Spa
# 1001  FckiBr0rL7Apg0qv6qHI0g  Advanced Dental Care Center
#
#                      address         city state postal_code  stars  \
# 0               921 Pearl St      Boulder    CO       80302    4.0
# 1        7000 NE Airport Way     Portland    OR       97218    4.0
# 2         4720 Hawthorne Ave     Portland    OR       97214    4.5
# 3         2566 Enterprise Rd  Orange City    FL       32763    3.0
# 4        1046 Memorial Dr SE      Atlanta    GA       30316    4.0
# ...                      ...          ...   ...         ...    ...
# 997        4113 S Orlando Dr      Sanford    FL       32773    4.0
# 998               40 High St      Medford    MA       02155    4.0
# 999       7417 NE Sandy Blvd     Portland    OR       97213    3.5
# 1000     2105 Lavista Rd 112      Atlanta    GA       30329    3.5
# 1001  5144 Morse Rd, Ste 200     Columbus    OH       43230    5.0
#
#       review_count  is_open                                         categories
# 0               86        1  Gastropubs, Food, Beer Gardens, Restaurants, B...
# 1              126        1  Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 2               13        1  Antiques, Fashion, Used, Vintage & Consignment...
# 3                8        1                         Beauty & Spas, Hair Salons
# 4               14        1  Gyms, Active Life, Interval Training Gyms, Fit...
# ...            ...      ...                                                ...
# 997             32        1  Car Dealers, Auto Parts & Supplies, Auto Repai...
# 998             55        1  Health & Medical, Massage Therapy, Massage, Be...
# 999             19        1               Bars, Nightlife, Adult Entertainment
# 1000            64        1                         Beauty & Spas, Nail Salons
# 1001            10        1  Health & Medical, Dentists, Cosmetic Dentists,...
#
# [1002 rows x 10 columns]

# %%
# Save the output into a csv file
business_data.to_csv(filepath + '\yelp_academic_dataset_business_sample_output.csv')

# %% [markdown]
# ## Review data set

# %%
# Write the first 1000 rows of json data into a sample file 
with open(filepath + '\yelp_academic_dataset_review.json', 'r', encoding='utf-8') as json_in_file: 
    with open(filepath + '\yelp_academic_dataset_review_sample.json', 'w', encoding='utf-8') as json_out_file:
        for index, line in enumerate(json_in_file): 
            json_out_file.write(line)
            if index > 1000:
                break

# %%
review_data = pd.read_json(filepath + '\yelp_academic_dataset_review_sample.json', lines=True)
review_data
# Out:
#                    review_id                 user_id             business_id  \
# 0     lWC-xP3rd6obsecCYsGZRg  ak0TdVmGKo4pwqdJSTLwWw  buF9druCkbuXLX526sGELQ
# 1     8bFej1QE5LXp4O05qjGqXA  YoVfDbnISlW0f7abNQACIg  RA4V8pr014UyUbDvI-LW2A
# 2     NDhkzczKjLshODbqDoNLSg  eC5evKn1TWDyHCyQAwguUw  _sS2LBIGNT5NQb6PD1Vtjw
# 3     T5fAqjjFooT4V0OeZyuk1w  SFQ1jcnGguO0LYWnbbftAA  0AzLzHfOJgL7ROwhdww2ew
# 4     sjm_uUcQVxab_EeLCqsYLg  0kA0PAJ8QFMeveQWHFqz2A  8zehGz9jnxPqXtOc7KaJxA
# ...                      ...                     ...                     ...
# 997   _RDqlhTily1mSmltqJAp0A  LK3NnWGLcnxU2i8PCHFaTA  VkV9tfARXGzUjqmRdze_WA
# 998   EKbOCFXKiR_APXI2mXEsmw  mcPMdBzh8EJWATLvHp5H0A  _rt-Z934kfFzgG19nTrIcQ
# 999   zagjXvZl-lsIOEwibvJnzQ  2Th9kCvo3yydQuHNgayDBw  eAPY_lYEo5FShEaeoXtQKA
# 1000  OzDCTMse4NnFJT57N2jq4w  gJNGt9dusI9rocfFXYrMSg  yYLNSTZB_AE0zTZAlGmdUw
# 1001  MpT9y9VCllbH7eJkSyVkow  JPPATjqdPT6KhdM4lgxwBg  RheCIakQLeUBT8Uia-5jyw
#
#       stars  useful  funny  cool  \
# 0         4       3      1     1
# 1         4       1      0     0
# 2         5       0      0     0
# 3         2       1      1     1
# 4         4       0      0     0
# ...     ...     ...    ...   ...
# 997       5       4      0     1
# 998       5       0      0     0
# 999       5       1      0     0
# 1000      5       1      0     0
# 1001      1       1      0     0
#
#                                                    text                date
# 0     Apparently Prides Osteria had a rough summer a... 2014-10-11 03:34:02
# 1     This store is pretty good. Not as great as Wal... 2015-07-03 20:38:25
# 2     I called WVM on the recommendation of a couple... 2013-05-28 20:38:06
# 3     I've stayed at many Marriott and Renaissance M... 2010-01-08 02:29:15
# 4     The food is always great here. The service fro... 2011-07-28 18:05:01
# ...                                                 ...                 ...
# 997   Went here for a birthday celebration.  Birthda... 2010-03-12 18:41:22
# 998   Great drinks at the tequila bar! Cierra recomm... 2016-05-07 02:12:44
# 999   We come here about once a week. Pizza is delic... 2016-08-25 15:40:15
# 1000  Very professional and passionate about their w... 2016-10-26 15:05:12
# 1001  Do not try to get a land loan from these peopl... 2012-06-25 23:58:30
#
# [1002 rows x 9 columns]

# %% [markdown]
# In this table, we will need all the information, so we can export the result with all columns

# %%
# Save the output into a csv file
review_data.to_csv(filepath + '\yelp_academic_dataset_review_sample_output.csv')

# %% [markdown]
# ## Tip data set

# %%
# Write the first 1000 rows of json data into a sample file 
with open(filepath + '\yelp_academic_dataset_tip.json', 'r', encoding='utf-8') as json_in_file: 
    with open(filepath + '\yelp_academic_dataset_tip_sample.json', 'w', encoding='utf-8') as json_out_file:
        for index, line in enumerate(json_in_file): 
            json_out_file.write(line)
            if index > 1000:
                break

# %%
tip_data = pd.read_json(filepath + '\yelp_academic_dataset_tip_sample.json', lines=True)
tip_data
# Out:
#                      user_id             business_id  \
# 0     WCjg0jdHXMlwbqS9tZUx8Q  ENwBByjpoa5Gg7tKgxqwLg
# 1     42-Z02y9bABShAGZhuSzrQ  jKO4Og6ucdX2-YCTKQVYjg
# 2     5u7E3LYp_3eB8dLuUBazXQ  9Bto7mky640ocgezVKSfVg
# 3     wDWoMG5N9oI4DJ-p7z8EBg  XWFjKtRGZ9khRGtGg2ZvaA
# 4     JmuFlorjjRshHTKzTwNtgg  mkrx0VhSMU3p3uhyJGCoWA
# ...                      ...                     ...
# 997   bFT7y7vTG1z63IyA7fsWsg  VznOFJQbZ9PZKrzdXkkiiA
# 998   UKHa4BDvcIvdVoiJsYYbnw  hwfF4tuCVBlFXY-K1pjeDA
# 999   HONe4kg3qn2AxNlABqsvCA  1OweB1FS_Q21b7IyqewGGQ
# 1000  I6B-COW6X7EATIQBH1gYLg  8HwwGSHlCEGbJiMDx_fkHg
# 1001  PmbHTq2DZ5r3CKXqPqsTXw  kpNfeWY6phS2YRVzQSevZg
#
#                                                    text                date  \
# 0                                  Carne asada chips... 2011-07-22 19:07:35
# 1     Best happy hour from 3pm to 6pm! $1 off martin... 2014-09-10 07:33:29
# 2     Nice people, skilled staff, clean location - b... 2013-12-13 23:23:41
# 3     1/2-price bowling & the "Very" Old Fashion are... 2017-07-11 23:07:16
# 4     Solid gold's. Great sauna. Great staff, too. E... 2016-11-30 08:46:36
# ...                                                 ...                 ...
# 997   instant seating great beer lovely shade on the... 2015-06-06 20:19:37
# 998   Great cuisine!! I was here for brunch!!! P.S: ... 2017-10-19 20:52:09
# 999   Their shrimp salad sandwich on challah bread i... 2011-10-02 04:02:06
# 1000                               Noodles were prefect 2013-08-24 03:43:21
# 1001       It's a disaster trying to get in this place. 2011-07-12 23:25:52
#
#       compliment_count
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 997                  0
# 998                  0
# 999                  0
# 1000                 0
# 1001                 0
#
# [1002 rows x 5 columns]

# %% [markdown]
# In this table, we will need all the information, so we can export the result with all columns

# %%
tip_data.to_csv(filepath + '\yelp_academic_dataset_tip_sample_output.csv')

# %% [markdown]
# ## User data set

# %%
# Write the first 1000 rows of json data into a sample file 
with open(filepath + '\yelp_academic_dataset_user.json', 'r', encoding='utf-8') as json_in_file: 
    with open(filepath + '\yelp_academic_dataset_user_sample.json', 'w', encoding='utf-8') as json_out_file:
        for index, line in enumerate(json_in_file): 
            json_out_file.write(line)
            if index > 1000:
                break

# %%
user_data = pd.read_json(filepath + '\yelp_academic_dataset_user_sample.json', lines=True)
user_data
# Out:
#                      user_id       name  review_count        yelping_since  \
# 0     q_QQ5kBBwlCcbL1s4NVK3g       Jane          1220  2005-03-14 20:26:35
# 1     dIIKEfOgo0KqUfGQvGikPg       Gabi          2136  2007-08-10 19:01:51
# 2     D6ErcUnFALnCQN4b1W_TlA      Jason           119  2007-02-07 15:47:53
# 3     JnPIjvC0cmooNDfsa9BmXg        Kat           987  2009-02-09 16:14:29
# 4     37Hc8hr3cw0iHLoPzLK6Ow  Christine           495  2008-03-03 04:57:05
# ...                      ...        ...           ...                  ...
# 997   VvmEMZxJk3zp9lyGDkjxRw      Nikki           229  2005-08-22 21:21:50
# 998   ZNJiYLz_6udX3ljXPZ9FJg       Olma           402  2006-06-24 05:14:10
# 999   ZH-OEKC-dOGQszEnXLpXnw       Dave           109  2009-08-27 12:42:43
# 1000  U3PbDEgVRJQrryCK_uiyVw       Kana            57  2009-04-16 02:06:47
# 1001  2i46aSHFa2rYbkYDlBD_mw       Eric           214  2009-02-24 09:15:57
#
#       useful  funny   cool                                              elite  \
# 0      15038  10030  11291       2006,2007,2008,2009,2010,2011,2012,2013,2014
# 1      21272  10289  18046  2007,2008,2009,2010,2011,2012,2013,2014,2015,2...
# 2        188    128    130                                          2010,2011
# 3       7234   4722   4035                      2009,2010,2011,2012,2013,2014
# 4       1577    727   1124                                     2009,2010,2011
# ...      ...    ...    ...                                                ...
# 997      565    271    401                                          2007,2008
# 998     1057    560    916                           2006,2007,2008,2009,2010
# 999      554    550    318                                     2011,2012,2013
# 1000      71     24     37
# 1001     821    397    461                                2009,2010,2011,2012
#
#                                                 friends  fans  ...  \
# 0     xBDpTUbai0DXrvxCe3X16Q, 7GPNBO496aecrjJfW6UWtg...  1357  ...
# 1     XPzYf9_mwG2eXYP2BAGSTA, 2LooM5dcIk2o01nftYdPIg...  1025  ...
# 2     GfB6sC4NJQvSI2ewbQrDNA, jhZtzZNNZJOU2YSZ6jPlXQ...    16  ...
# 3     HQZPQhKMwRAyS6BCselVWQ, kP2U1s_sjQfHO9grxiyDTA...   420  ...
# 4     -Q88pZUcrfN0BLBDp-bkAQ, etPn4Pv1Gc4cRZjRgB_BOw...    47  ...
# ...                                                 ...   ...  ...
# 997   sZUC9GbwvDHWrHl0D_d2dA, 89yr7wNIk8TE03yKfTRLuQ...    20  ...
# 998   hGenPmSp8JEg2w5pelLdKg, 0XXIv9a0LWiaCjAkurjMMQ...    35  ...
# 999   P2zPtRoac-_ltqqTlPXM0Q, eLOliEa71F4o0P39lWuk9g...    12  ...
# 1000  i1TJRbN1HTJpv88SzN8vqA, P6VJObgsgQLHJWBz7XUwWQ...     7  ...
# 1001  6tVk1wPOKEN180gsEAabtg, rPJbjfn29W3vhOS4kc-0bQ...    38  ...
#
#       compliment_more  compliment_profile  compliment_cute  compliment_list  \
# 0                 163                 190              361              147
# 1                  87                  94              232               96
# 2                   1                   3                0                0
# 3                 129                  93              219               90
# 4                  19                  32               16               15
# ...               ...                 ...              ...              ...
# 997                 4                   7                6                4
# 998                 7                  11               15                3
# 999                 2                   3                2                0
# 1000                0                   0                1                0
# 1001                6                   4                5               10
#
#       compliment_note  compliment_plain  compliment_cool  compliment_funny  \
# 0                1212              5691             2541              2541
# 1                1187              3293             2205              2205
# 2                   5                20               31                31
# 3                1120              4510             1566              1566
# 4                  77               131              310               310
# ...               ...               ...              ...               ...
# 997                17                29               62                62
# 998                35               168              199               199
# 999                29                51               76                76
# 1000                1                 5                2                 2
# 1001               55               145              104               104
#
#       compliment_writer  compliment_photos
# 0                   815                323
# 1                   472                294
# 2                     3                  1
# 3                   391                326
# 4                    98                 44
# ...                 ...                ...
# 997                  17                  2
# 998                  43                 16
# 999                  23                  7
# 1000                  0                  2
# 1001                 18                  4
#
# [1002 rows x 22 columns]

# %%
print(user_data.columns)
# Out:
# Index(['user_id', 'name', 'review_count', 'yelping_since', 'useful', 'funny',
#        'cool', 'elite', 'friends', 'fans', 'average_stars', 'compliment_hot',
#        'compliment_more', 'compliment_profile', 'compliment_cute',
#        'compliment_list', 'compliment_note', 'compliment_plain',
#        'compliment_cool', 'compliment_funny', 'compliment_writer',
#        'compliment_photos'],
#       dtype='object')

# %% [markdown]
# To achiever the goal, we need the following columns:
# - user_id
# - name
# - review_count
# - yelping_since
# - useful
# - funny
# - cool
# - fans
# - average_stars

# %%
user_data = user_data[['user_id', 'name', 'review_count', 'yelping_since', 'useful', 'funny', 'cool', 'fans', 'average_stars']]
user_data
# Out:
#                      user_id       name  review_count        yelping_since  \
# 0     q_QQ5kBBwlCcbL1s4NVK3g       Jane          1220  2005-03-14 20:26:35
# 1     dIIKEfOgo0KqUfGQvGikPg       Gabi          2136  2007-08-10 19:01:51
# 2     D6ErcUnFALnCQN4b1W_TlA      Jason           119  2007-02-07 15:47:53
# 3     JnPIjvC0cmooNDfsa9BmXg        Kat           987  2009-02-09 16:14:29
# 4     37Hc8hr3cw0iHLoPzLK6Ow  Christine           495  2008-03-03 04:57:05
# ...                      ...        ...           ...                  ...
# 997   VvmEMZxJk3zp9lyGDkjxRw      Nikki           229  2005-08-22 21:21:50
# 998   ZNJiYLz_6udX3ljXPZ9FJg       Olma           402  2006-06-24 05:14:10
# 999   ZH-OEKC-dOGQszEnXLpXnw       Dave           109  2009-08-27 12:42:43
# 1000  U3PbDEgVRJQrryCK_uiyVw       Kana            57  2009-04-16 02:06:47
# 1001  2i46aSHFa2rYbkYDlBD_mw       Eric           214  2009-02-24 09:15:57
#
#       useful  funny   cool  fans  average_stars
# 0      15038  10030  11291  1357           3.85
# 1      21272  10289  18046  1025           4.09
# 2        188    128    130    16           3.76
# 3       7234   4722   4035   420           3.77
# 4       1577    727   1124    47           3.72
# ...      ...    ...    ...   ...            ...
# 997      565    271    401    20           3.78
# 998     1057    560    916    35           3.76
# 999      554    550    318    12           3.68
# 1000      71     24     37     7           4.42
# 1001     821    397    461    38           3.71
#
# [1002 rows x 9 columns]

# %%
user_data.to_csv(filepath + '\yelp_academic_dataset_user_sample_output.csv')

# %% [markdown]
# ## Time data

# %%
with open(filepath + '\yelp_academic_dataset_checkin.json', 'r', encoding='utf-8') as json_in_file: 
    with open(filepath + '\yelp_academic_dataset_checkin_sample.json', 'w', encoding='utf-8') as json_out_file:
        for index, line in enumerate(json_in_file): 
            json_out_file.write(line)
            if index > 1000:
                break

# %%
checkin_data = pd.read_json(filepath + '\yelp_academic_dataset_checkin_sample.json', lines=True)
checkin_data
# Out:
#                  business_id  \
# 0     --0r8K_AQ4FZfLsX3ZYRDA
# 1     --0zrn43LEaB4jUWTQH_Bg
# 2     --164t1nclzzmca7eDiJMw
# 3     --2aF9NhXnNVpDV0KS3xBQ
# 4     --2mEJ63SC_8_08_jGgVIg
# ...                      ...
# 997   -SjRCXID7eXewqloY3V86w
# 998   -Sjrz1Mt9RY4r6ibxzGs0Q
# 999   -Sk9ZND7V2x8RuauMH0FRw
# 1000  -SkNedh2bJHPOcKfoFlTvg
# 1001  -SkwKPbo5oK1-NtKkupNvw
#
#                                                    date
# 0                                   2017-09-03 17:13:59
# 1     2010-10-08 22:21:20, 2010-11-01 21:29:14, 2010...
# 2     2010-02-26 02:06:53, 2010-02-27 08:00:09, 2010...
# 3     2014-11-03 16:35:35, 2015-01-30 18:16:03, 2015...
# 4     2010-12-15 17:10:46, 2013-12-28 00:27:54, 2015...
# ...                                                 ...
# 997   2015-12-13 02:48:00, 2016-01-21 22:31:31, 2016...
# 998   2016-08-08 19:23:27, 2016-08-15 16:03:29, 2016...
# 999   2010-09-05 02:04:25, 2010-10-15 22:48:00, 2010...
# 1000  2013-09-01 02:54:45, 2013-10-22 16:59:13, 2013...
# 1001  2010-09-11 20:23:45, 2011-05-26 16:24:35, 2011...
#
# [1002 rows x 2 columns]

# %%
# Filter the checkin data which are older than 2018 
checkin_data['date'] = checkin_data['date'].str.split(',')

# %%
checkin_data
# Out:
#                  business_id  \
# 0     --0r8K_AQ4FZfLsX3ZYRDA
# 1     --0zrn43LEaB4jUWTQH_Bg
# 2     --164t1nclzzmca7eDiJMw
# 3     --2aF9NhXnNVpDV0KS3xBQ
# 4     --2mEJ63SC_8_08_jGgVIg
# ...                      ...
# 997   -SjRCXID7eXewqloY3V86w
# 998   -Sjrz1Mt9RY4r6ibxzGs0Q
# 999   -Sk9ZND7V2x8RuauMH0FRw
# 1000  -SkNedh2bJHPOcKfoFlTvg
# 1001  -SkwKPbo5oK1-NtKkupNvw
#
#                                                    date
# 0                                 [2017-09-03 17:13:59]
# 1     [2010-10-08 22:21:20,  2010-11-01 21:29:14,  2...
# 2     [2010-02-26 02:06:53,  2010-02-27 08:00:09,  2...
# 3     [2014-11-03 16:35:35,  2015-01-30 18:16:03,  2...
# 4     [2010-12-15 17:10:46,  2013-12-28 00:27:54,  2...
# ...                                                 ...
# 997   [2015-12-13 02:48:00,  2016-01-21 22:31:31,  2...
# 998   [2016-08-08 19:23:27,  2016-08-15 16:03:29,  2...
# 999   [2010-09-05 02:04:25,  2010-10-15 22:48:00,  2...
# 1000  [2013-09-01 02:54:45,  2013-10-22 16:59:13,  2...
# 1001  [2010-09-11 20:23:45,  2011-05-26 16:24:35,  2...
#
# [1002 rows x 2 columns]

# %%
def convert_to_date(d): 
    x = pd.to_datetime(d)
    return x[x >= '2018-01-01'].tolist()

checkin_data['date'] = checkin_data['date'].apply(convert_to_date)

# %%
checkin_data
# Out:
#                  business_id  \
# 0     --0r8K_AQ4FZfLsX3ZYRDA
# 1     --0zrn43LEaB4jUWTQH_Bg
# 2     --164t1nclzzmca7eDiJMw
# 3     --2aF9NhXnNVpDV0KS3xBQ
# 4     --2mEJ63SC_8_08_jGgVIg
# ...                      ...
# 997   -SjRCXID7eXewqloY3V86w
# 998   -Sjrz1Mt9RY4r6ibxzGs0Q
# 999   -Sk9ZND7V2x8RuauMH0FRw
# 1000  -SkNedh2bJHPOcKfoFlTvg
# 1001  -SkwKPbo5oK1-NtKkupNvw
#
#                                                    date
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3     [2018-02-12 23:13:56, 2019-04-22 19:34:48, 202...
# 4                                                    []
# ...                                                 ...
# 997                                                  []
# 998   [2018-01-01 21:54:06, 2018-01-19 20:58:06, 201...
# 999                                                  []
# 1000  [2018-01-02 19:45:42, 2018-01-12 23:19:41, 201...
# 1001  [2018-08-16 18:17:05, 2018-09-09 23:06:06, 201...
#
# [1002 rows x 2 columns]

# %%
checkin_data = checkin_data.explode('date').reset_index(drop=True)

# %%
checkin_data = checkin_data.dropna()
checkin_data
# Out:
#                   business_id                date
# 3      --2aF9NhXnNVpDV0KS3xBQ 2018-02-12 23:13:56
# 4      --2aF9NhXnNVpDV0KS3xBQ 2019-04-22 19:34:48
# 5      --2aF9NhXnNVpDV0KS3xBQ 2020-12-29 16:22:00
# 10     --JKSSgnfoOjVDFGv692BA 2018-09-12 14:04:02
# 12     --Q3mAcX9t63f7Xcbn7LVA 2020-07-15 22:29:52
# ...                       ...                 ...
# 26308  -SkwKPbo5oK1-NtKkupNvw 2018-09-09 23:06:06
# 26309  -SkwKPbo5oK1-NtKkupNvw 2019-04-29 00:09:17
# 26310  -SkwKPbo5oK1-NtKkupNvw 2019-09-05 23:10:34
# 26311  -SkwKPbo5oK1-NtKkupNvw 2020-05-02 18:47:48
# 26312  -SkwKPbo5oK1-NtKkupNvw 2020-08-05 20:01:51
#
# [25947 rows x 2 columns]

# %%
checkin_data.to_csv(filepath + '\yelp_academic_dataset_checkin_sample_output.csv')
